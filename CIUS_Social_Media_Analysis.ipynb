# %% [markdown]
# # Social Media Use & Mental Health Survey

# %%
# Import required libraries
import pandas as pd
import numpy as np

# %%
# --- Robust loader for CIUS PUMF (SAS) ---
from pathlib import Path
import pandas as pd

#Locate the .sas7bdat file anywhere under the project
root = Path.cwd()
candidates = list(root.rglob("cius_pumf.sas7bdat"))
print("Found SAS files:", [str(p.relative_to(root)) for p in candidates])

if not candidates:
    raise FileNotFoundError("Could not find 'cius_pumf.sas7bdat'. "
                            "Make sure it’s in Data/Data/Layouts/")

file_path = candidates[0]  # take the first match
# Out:
# Found SAS files: ['Data\\Data\\cius_pumf.sas7bdat']

# %%
cius = pd.read_sas(str(file_path), format="sas7bdat", encoding="latin1")

print("Loaded CIUS PUMF")
# Out:
# Loaded CIUS PUMF

# %%
print("Shape:", cius.shape)
print("First 20 columns:", list(cius.columns[:20]))
# Out:
# Shape: (25118, 1342)
# First 20 columns: ['PUMFID', 'PROVINCE', 'LUC_RST', 'RRS_G12', 'AGE_GRP', 'GENDER', 'ABM', 'EMP', 'ED_10', 'EDU', 'AC_010A', 'AC_020A', 'AC_030A', 'AC_040A', 'AC_040B', 'AC_040C', 'AC_040D', 'AC_G040F', 'AC_G040H', 'AC_G040L']

# %%
cius.head()
# Out:
#      PUMFID  PROVINCE  LUC_RST  RRS_G12  AGE_GRP  GENDER  ABM  EMP  ED_10  \
# 0  100000.0      35.0      1.0      1.0      6.0     2.0  2.0  2.0    2.0
# 1  100001.0      24.0      1.0      2.0      3.0     2.0  2.0  1.0    2.0
# 2  100002.0      46.0      1.0      5.0      1.0     1.0  2.0  2.0    1.0
# 3  100003.0      59.0      1.0      1.0      6.0     2.0  2.0  2.0    2.0
# 4  100004.0      24.0      1.0      2.0      5.0     1.0  2.0  2.0    2.0
#
#    EDU  ...      WRPG991      WRPG992      WRPG993      WRPG994      WRPG995  \
# 0  2.0  ...     0.850140     0.835827   943.351438  1063.999737  1211.319191
# 1  3.0  ...  2674.191778     0.906637  1232.584149  1180.189236  1162.019616
# 2  1.0  ...     4.778324  2669.406260  3454.854131  3711.465912     4.863419
# 3  1.0  ...   591.713678  1484.953681   672.667980   543.881805  1117.693783
# 4  2.0  ...     0.571829     0.738236     0.674246   569.744900     0.637382
#
#         WRPG996      WRPG997      WRPG998      WRPG999      WRPG1000
# 0   1102.319607  1134.841957     0.764067     0.901000   1238.133901
# 1      0.825672  2622.753088  1413.300686  1238.514401   1238.073837
# 2  10567.939256     8.864064     3.770998  3392.246179  16573.401281
# 3      0.691681   743.797051   596.919337   539.860676      0.738150
# 4    696.952219     0.605033   553.936031     0.660384      0.755782
#
# [5 rows x 1342 columns]

# %% [markdown]
# ### Column Selection and Renaming
# #### The original CIUS dataset contains 1,342 columns. To align this data with our survey, we will select only the 16 specific variables we need.
#
# #### At the same time, we will rename these columns to more descriptive and "friendly" labels for easier analysis.

# %%
# 16 columns we need
cols16 = [
    "PROVINCE", "AGE_GRP", "GENDER", "EDU", "EMP", "HINCQUIN", "WTPG",
    "TS_010A", "TS_020A", "UI_110A", "UI_110B", "UI_110C",
    "DS_070A", "DS_070B", "GHCOMP", "ONL_SHOP"
]

# Check which ones exist in your CIUS file
available_cols = [c for c in cols16 if c in cius.columns]
missing_cols = [c for c in cols16 if c not in cius.columns]

print("Found columns:", available_cols)
print("Missing columns:", missing_cols)
# Out:
# Found columns: ['PROVINCE', 'AGE_GRP', 'GENDER', 'EDU', 'EMP', 'HINCQUIN', 'WTPG', 'TS_010A', 'TS_020A', 'UI_110A', 'UI_110B', 'UI_110C', 'DS_070A', 'DS_070B', 'GHCOMP', 'ONL_SHOP']
# Missing columns: []

# %%
column_mapping = {
    "PROVINCE": "Province",
    "AGE_GRP": "Age",
    "GENDER": "Gender",
    "EDU": "Education",
    "EMP": "Employment",
    "HINCQUIN": "Income_Group",
    "WTPG": "Weight",

    # TS_* are about relationships & online communication
    "TS_010A": "Rel_Satisfaction",          # satisfaction with relationships (friends)
    "TS_020A": "Online_Contact_Freq",       # how often use internet to communicate with friends

    # UI_110* are *effects* of online use
    "UI_110A": "SM_Interfere_Rel",          # Does online use interfere with relationships?
    "UI_110B": "SM_Interfere_Life",         # Interfere with other aspects of life?
    "UI_110C": "SM_Anxious_Envious",        # Make you feel anxious / depressed / envious?

    # DS_070* are *AI awareness*, not stress/sleep
    "DS_070A": "SM_AI_Chatbot",             # Ever noticed AI in chatbots?
    "DS_070B": "SM_AI_Email",               # Ever noticed AI in emails?

    # Household composition
    "GHCOMP": "Household_Type",

    # Online shopping
    "ONL_SHOP": "Online_Shopping"
}

cius = cius.rename(columns=column_mapping)

# %%
cius.columns
# Out:
# Index(['PUMFID', 'Province', 'LUC_RST', 'RRS_G12', 'Age', 'Gender', 'ABM',
#        'Employment', 'ED_10', 'Education',
#        ...
#        'WRPG991', 'WRPG992', 'WRPG993', 'WRPG994', 'WRPG995', 'WRPG996',
#        'WRPG997', 'WRPG998', 'WRPG999', 'WRPG1000'],
#       dtype='str', length=1342)

# %%
valid_ranges = {
    "Province": {10, 11, 12, 13, 24, 35, 46, 47, 48, 59},
    "Age": {1, 2, 3, 4, 5, 6},
    "Gender": {1, 2},
    "Education": {1, 2, 3},
    "Employment": {1, 2},
    "Income_Group": {1, 2, 3, 4, 5},

    # Rel_Satisfaction 1–5 only, drop 6/7/8/9
    "Rel_Satisfaction": {1, 2, 3, 4, 5},

    # Online_Contact_Freq 01–06 only, drop 07/96/97/98/99
    "Online_Contact_Freq": {1, 2, 3, 4, 5, 6},

    # All these are Yes / No (1/2). 6/7/8/9 = missing / DK / refusal
    "SM_Interfere_Rel": {1, 2},
    "SM_Interfere_Life": {1, 2},
    "SM_Anxious_Envious": {1, 2},
    "SM_AI_Chatbot": {1, 2},
    "SM_AI_Email": {1, 2},

    # Household type 1–4 (skip 6/7/8/9)
    "Household_Type": {1, 2, 3, 4},

    # Online shopping 1,2,3,4,5 in CIUS, but you probably only want 1/2
    "Online_Shopping": {1, 2}
}

for col, allowed in valid_ranges.items():
    cius.loc[~cius[col].isin(allowed), col] = pd.NA

# Optionally drop rows with any NA:
# cius_clean = cius.dropna().reset_index(drop=True)
# or keep them and handle missing in analysis

# %% [markdown]
# #### Recoding Column Values
# #### To make the data easier to understand, we will convert the numeric codes in our categorical columns into human-readable text values.
#
# #### We will create a separate mapping dictionary for each column. Then, we'll use the .map() method to apply these transformations, changing codes into descriptive labels

# %%
label_mappings = {
    "Province": {
        10: "Newfoundland and Labrador",
        11: "Prince Edward Island",
        12: "Nova Scotia",
        13: "New Brunswick",
        24: "Quebec",
        35: "Ontario",
        46: "Manitoba",
        47: "Saskatchewan",
        48: "Alberta",
        59: "British Columbia"
    },
    "Age": {
        1: "15–24 years",
        2: "25–34 years",
        3: "35–44 years",
        4: "45–54 years",
        5: "55–64 years",
        6: "65 years and over"
    },
    "Gender": {
        1: "Male",
        2: "Female"
    },
    "Education": {
        1: "High school or less",
        2: "Some post-secondary (incl. certificate)",
        3: "University degree"
    },
    "Employment": {
        1: "Employed",
        2: "Not employed"
    },
    "Income_Group": {
        1: "≤ $42,256",
        2: "$42,257 – $72,366",
        3: "$72,367 – $107,480",
        4: "$107,481 – $163,750",
        5: "≥ $163,751"
    },
    "Rel_Satisfaction": {
        1: "Completely dissatisfied",
        2: "Somewhat dissatisfied",
        3: "Neutral",
        4: "Somewhat satisfied",
        5: "Completely satisfied"
    },
    "Online_Contact_Freq": {
        1: "Everyday",
        2: "A few times a week",
        3: "Once a week",
        4: "2–3 times a month",
        5: "Once a month",
        6: "Not in the past month"
    },
    "Online_Shopping": {
        1: "Online shopper (≥ $1)",
        2: "Did not shop online"
    }
}

for col, mapping in label_mappings.items():
    cius[col] = cius[col].map(mapping)

# %%
yn_map = {1: "Yes", 2: "No"}

for col in ["SM_Interfere_Rel", "SM_Interfere_Life",
            "SM_Anxious_Envious", "SM_AI_Chatbot", "SM_AI_Email"]:
    cius[col] = cius[col].map(yn_map)

# %%
hh_map = {
    1: "Family with children <18",
    2: "Family without children <18",
    3: "Single-person household",
    4: "Other household type"
}

cius["Household_Type"] = cius["Household_Type"].map(hh_map)

# %%
cius.head()
# Out:
#      PUMFID          Province  LUC_RST  RRS_G12                Age  Gender  \
# 0  100000.0           Ontario      1.0      1.0  65 years and over  Female
# 1  100001.0            Quebec      1.0      2.0        35–44 years  Female
# 2  100002.0          Manitoba      1.0      5.0        15–24 years    Male
# 3  100003.0  British Columbia      1.0      1.0  65 years and over  Female
# 4  100004.0            Quebec      1.0      2.0        55–64 years    Male
#
#    ABM    Employment  ED_10                                Education  ...  \
# 0  2.0  Not employed    2.0  Some post-secondary (incl. certificate)  ...
# 1  2.0      Employed    2.0                        University degree  ...
# 2  2.0  Not employed    1.0                      High school or less  ...
# 3  2.0  Not employed    2.0                      High school or less  ...
# 4  2.0  Not employed    2.0  Some post-secondary (incl. certificate)  ...
#
#        WRPG991      WRPG992      WRPG993      WRPG994      WRPG995  \
# 0     0.850140     0.835827   943.351438  1063.999737  1211.319191
# 1  2674.191778     0.906637  1232.584149  1180.189236  1162.019616
# 2     4.778324  2669.406260  3454.854131  3711.465912     4.863419
# 3   591.713678  1484.953681   672.667980   543.881805  1117.693783
# 4     0.571829     0.738236     0.674246   569.744900     0.637382
#
#         WRPG996      WRPG997      WRPG998      WRPG999      WRPG1000
# 0   1102.319607  1134.841957     0.764067     0.901000   1238.133901
# 1      0.825672  2622.753088  1413.300686  1238.514401   1238.073837
# 2  10567.939256     8.864064     3.770998  3392.246179  16573.401281
# 3      0.691681   743.797051   596.919337   539.860676      0.738150
# 4    696.952219     0.605033   553.936031     0.660384      0.755782
#
# [5 rows x 1342 columns]

# %%
cius.dtypes
# Out:
# PUMFID      float64
# Province        str
# LUC_RST     float64
# RRS_G12     float64
# Age             str
#              ...
# WRPG996     float64
# WRPG997     float64
# WRPG998     float64
# WRPG999     float64
# WRPG1000    float64
# Length: 1342, dtype: object

# %%
final_cols = [
    "Province",
    "Age",
    "Gender",
    "Education",
    "Employment",
    "Income_Group",
    "Weight",

    "Rel_Satisfaction",       # TS_010A
    "Online_Contact_Freq",    # TS_020A

    "SM_Interfere_Rel",       # UI_110A
    "SM_Interfere_Life",      # UI_110B
    "SM_Anxious_Envious",     # UI_110C

    "SM_AI_Chatbot",          # DS_070A
    "SM_AI_Email",            # DS_070B

    "Household_Type",         # GHCOMP
    "Online_Shopping"         # ONL_SHOP
]

# %%
cius_16 = cius[final_cols].copy()

# %%
cius_16.to_csv("CIUS_SocialMedia_Clean_Labeled.csv", index=False)
print("Saved file with shape:", cius_16.shape)
# Out:
# Saved file with shape: (25118, 16)

# %%
cius_16.head()
# Out:
#            Province                Age  Gender  \
# 0           Ontario  65 years and over  Female
# 1            Quebec        35–44 years  Female
# 2          Manitoba        15–24 years    Male
# 3  British Columbia  65 years and over  Female
# 4            Quebec        55–64 years    Male
#
#                                  Education    Employment         Income_Group  \
# 0  Some post-secondary (incl. certificate)  Not employed    $42,257 – $72,366
# 1                        University degree      Employed    $42,257 – $72,366
# 2                      High school or less  Not employed    $42,257 – $72,366
# 3                      High school or less  Not employed   $72,367 – $107,480
# 4  Some post-secondary (incl. certificate)  Not employed  $107,481 – $163,750
#
#         Weight      Rel_Satisfaction Online_Contact_Freq SM_Interfere_Rel  \
# 0  1091.470037                   NaN                 NaN              NaN
# 1  1264.083653  Completely satisfied            Everyday               No
# 2  3413.046802  Completely satisfied            Everyday               No
# 3   627.395486  Completely satisfied                 NaN               No
# 4   585.544542  Completely satisfied  A few times a week               No
#
#   SM_Interfere_Life SM_Anxious_Envious SM_AI_Chatbot SM_AI_Email  \
# 0               NaN                NaN           NaN         NaN
# 1                No                 No           Yes         Yes
# 2                No                 No            No          No
# 3                No                 No            No          No
# 4                No                 No           Yes         Yes
#
#                 Household_Type        Online_Shopping
# 0      Single-person household                    NaN
# 1     Family with children <18  Online shopper (≥ $1)
# 2     Family with children <18    Did not shop online
# 3      Single-person household    Did not shop online
# 4  Family without children <18  Online shopper (≥ $1)

# %%
cius_16.isnull().sum()
# Out:
# Province                  0
# Age                       3
# Gender                    0
# Education              1370
# Employment             1421
# Income_Group              0
# Weight                    0
# Rel_Satisfaction       2475
# Online_Contact_Freq    4179
# SM_Interfere_Rel       2231
# SM_Interfere_Life      2231
# SM_Anxious_Envious     2231
# SM_AI_Chatbot          3016
# SM_AI_Email            3016
# Household_Type          731
# Online_Shopping        2467
# dtype: int64

# %%
not_asked_cols = [
    "Rel_Satisfaction", "Online_Contact_Freq",
    "SM_Interfere_Rel", "SM_Interfere_Life", "SM_Anxious_Envious",
    "SM_AI_Chatbot", "SM_AI_Email",
    "Household_Type", "Online_Shopping"
]

for col in not_asked_cols:
    cius_16[col] = cius_16[col].fillna("Not asked")

# %%
# Fix true missing demographic responses
cius_16["Age"] = cius_16["Age"].fillna("Unknown")
cius_16["Education"] = cius_16["Education"].fillna("Unknown")
cius_16["Employment"] = cius_16["Employment"].fillna("Unknown")

# %% [markdown]
# Not asked” = the respondent was not supposed to answer that question due to survey design.
#
# It does NOT mean:
#
# missing
#
# null
#
# skipped
#
# error
#
# drop row
#
# It means:
#
# Survey logic instructed: do not ask this person.

# %%
cius_16.isnull().sum()
# Out:
# Province               0
# Age                    0
# Gender                 0
# Education              0
# Employment             0
# Income_Group           0
# Weight                 0
# Rel_Satisfaction       0
# Online_Contact_Freq    0
# SM_Interfere_Rel       0
# SM_Interfere_Life      0
# SM_Anxious_Envious     0
# SM_AI_Chatbot          0
# SM_AI_Email            0
# Household_Type         0
# Online_Shopping        0
# dtype: int64

# %% [markdown]
# For skip pattern variables
#
# (relationship satisfaction, online frequency, AI chatbot/email, stress/anxiety, online shopping)
#
# → "Not asked" is correct.
#
# For demographic variables
#
# (Age, Education, Employment)
#
# → Users refused or skipped → these are true missing values
# → Use "Unknown" so Tableau groups them, not drops them.

# %%
cius_df = cius_16.copy()
cius_df.shape
# Out:
# (25118, 16)

# %%
cius_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25118 entries, 0 to 25117
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Province             25118 non-null  str
#  1   Age                  25118 non-null  str
#  2   Gender               25118 non-null  str
#  3   Education            25118 non-null  str
#  4   Employment           25118 non-null  str
#  5   Income_Group         25118 non-null  str
#  6   Weight               25118 non-null  float64
#  7   Rel_Satisfaction     25118 non-null  str
#  8   Online_Contact_Freq  25118 non-null  str
#  9   SM_Interfere_Rel     25118 non-null  str
#  10  SM_Interfere_Life    25118 non-null  str
#  11  SM_Anxious_Envious   25118 non-null  str
#  12  SM_AI_Chatbot        25118 non-null  str
#  13  SM_AI_Email          25118 non-null  str
#  14  Household_Type       25118 non-null  str
#  15  Online_Shopping      25118 non-null  str
# dtypes: float64(1), str(15)
# memory usage: 7.1 MB

# %%
cius_df.isnull().sum()
# Out:
# Province               0
# Age                    0
# Gender                 0
# Education              0
# Employment             0
# Income_Group           0
# Weight                 0
# Rel_Satisfaction       0
# Online_Contact_Freq    0
# SM_Interfere_Rel       0
# SM_Interfere_Life      0
# SM_Anxious_Envious     0
# SM_AI_Chatbot          0
# SM_AI_Email            0
# Household_Type         0
# Online_Shopping        0
# dtype: int64

# %%
cius_df['Province'].value_counts()
# Out:
# Province
# Ontario                      6462
# Quebec                       5665
# British Columbia             3371
# Alberta                      2016
# Saskatchewan                 1532
# Manitoba                     1496
# Nova Scotia                  1308
# Newfoundland and Labrador    1191
# Prince Edward Island         1064
# New Brunswick                1013
# Name: count, dtype: int64

# %%
cius_df['Weight'].value_counts()
# Out:
# Weight
# 851.205191     93
# 795.635082     84
# 1028.210795    78
# 1083.542252    76
# 1225.328538    67
#                ..
# 300.266456      1
# 281.864625      1
# 4431.585019     1
# 585.700925      1
# 834.195002      1
# Name: count, Length: 2953, dtype: int64

# %%
cius_df['Employment'].value_counts()
# Out:
# Employment
# Employed        13197
# Not employed    10500
# Unknown          1421
# Name: count, dtype: int64

# %%
cius_df.columns
# Out:
# Index(['Province', 'Age', 'Gender', 'Education', 'Employment', 'Income_Group',
#        'Weight', 'Rel_Satisfaction', 'Online_Contact_Freq', 'SM_Interfere_Rel',
#        'SM_Interfere_Life', 'SM_Anxious_Envious', 'SM_AI_Chatbot',
#        'SM_AI_Email', 'Household_Type', 'Online_Shopping'],
#       dtype='str')

# %%
cius_df.head()
# Out:
#            Province                Age  Gender  \
# 0           Ontario  65 years and over  Female
# 1            Quebec        35–44 years  Female
# 2          Manitoba        15–24 years    Male
# 3  British Columbia  65 years and over  Female
# 4            Quebec        55–64 years    Male
#
#                                  Education    Employment         Income_Group  \
# 0  Some post-secondary (incl. certificate)  Not employed    $42,257 – $72,366
# 1                        University degree      Employed    $42,257 – $72,366
# 2                      High school or less  Not employed    $42,257 – $72,366
# 3                      High school or less  Not employed   $72,367 – $107,480
# 4  Some post-secondary (incl. certificate)  Not employed  $107,481 – $163,750
#
#         Weight      Rel_Satisfaction Online_Contact_Freq SM_Interfere_Rel  \
# 0  1091.470037             Not asked           Not asked        Not asked
# 1  1264.083653  Completely satisfied            Everyday               No
# 2  3413.046802  Completely satisfied            Everyday               No
# 3   627.395486  Completely satisfied           Not asked               No
# 4   585.544542  Completely satisfied  A few times a week               No
#
#   SM_Interfere_Life SM_Anxious_Envious SM_AI_Chatbot SM_AI_Email  \
# 0         Not asked          Not asked     Not asked   Not asked
# 1                No                 No           Yes         Yes
# 2                No                 No            No          No
# 3                No                 No            No          No
# 4                No                 No           Yes         Yes
#
#                 Household_Type        Online_Shopping
# 0      Single-person household              Not asked
# 1     Family with children <18  Online shopper (≥ $1)
# 2     Family with children <18    Did not shop online
# 3      Single-person household    Did not shop online
# 4  Family without children <18  Online shopper (≥ $1)

# %%
cius_df['Age'].value_counts()
# Out:
# Age
# 65 years and over    8346
# 55–64 years          5190
# 35–44 years          4022
# 45–54 years          3875
# 25–34 years          2756
# 15–24 years           926
# Unknown                 3
# Name: count, dtype: int64

# %%
cius_df['Rel_Satisfaction'].value_counts()
# Out:
# Rel_Satisfaction
# Completely satisfied       10532
# Somewhat satisfied          7616
# Neutral                     3514
# Not asked                   2475
# Somewhat dissatisfied        643
# Completely dissatisfied      338
# Name: count, dtype: int64

# %% [markdown]
# #### Quick overview

# %%
print("rows, cols : ", cius_df.shape)
display(cius_df.head(10))
# Out:
# rows, cols :  (25118, 16)
#            Province                Age  Gender  \
# 0           Ontario  65 years and over  Female
# 1            Quebec        35–44 years  Female
# 2          Manitoba        15–24 years    Male
# 3  British Columbia  65 years and over  Female
# 4            Quebec        55–64 years    Male
# 5      Saskatchewan        45–54 years    Male
# 6     New Brunswick  65 years and over    Male
# 7            Quebec        25–34 years  Female
# 8            Quebec        45–54 years    Male
# 9           Alberta  65 years and over    Male
#
#                                  Education    Employment         Income_Group  \
# 0  Some post-secondary (incl. certificate)  Not employed    $42,257 – $72,366
# 1                        University degree      Employed    $42,257 – $72,366
# 2                      High school or less  Not employed    $42,257 – $72,366
# 3                      High school or less  Not employed   $72,367 – $107,480
# 4  Some post-secondary (incl. certificate)  Not employed  $107,481 – $163,750
# 5                      High school or less      Employed    $42,257 – $72,366
# 6  Some post-secondary (incl. certificate)  Not employed    $42,257 – $72,366
# 7  Some post-secondary (incl. certificate)      Employed    $42,257 – $72,366
# 8  Some post-secondary (incl. certificate)      Employed           ≥ $163,751
# 9  Some post-secondary (incl. certificate)  Not employed           ≥ $163,751
#
#         Weight      Rel_Satisfaction Online_Contact_Freq SM_Interfere_Rel  \
# 0  1091.470037             Not asked           Not asked        Not asked
# 1  1264.083653  Completely satisfied            Everyday               No
# 2  3413.046802  Completely satisfied            Everyday               No
# 3   627.395486  Completely satisfied           Not asked               No
# 4   585.544542  Completely satisfied  A few times a week               No
# 5   378.876698               Neutral           Not asked               No
# 6   433.002600  Completely satisfied  A few times a week               No
# 7  4060.051301               Neutral            Everyday               No
# 8   762.357914    Somewhat satisfied         Once a week               No
# 9   915.245450  Completely satisfied            Everyday               No
#
#   SM_Interfere_Life SM_Anxious_Envious SM_AI_Chatbot SM_AI_Email  \
# 0         Not asked          Not asked     Not asked   Not asked
# 1                No                 No           Yes         Yes
# 2                No                 No            No          No
# 3                No                 No            No          No
# 4                No                 No           Yes         Yes
# 5                No                 No            No          No
# 6                No                 No            No          No
# 7                No                 No           Yes          No
# 8                No                 No            No          No
# 9                No                 No            No          No
#
#                 Household_Type        Online_Shopping
# 0      Single-person household              Not asked
# 1     Family with children <18  Online shopper (≥ $1)
# 2     Family with children <18    Did not shop online
# 3      Single-person household    Did not shop online
# 4  Family without children <18  Online shopper (≥ $1)
# 5  Family without children <18    Did not shop online
# 6  Family without children <18    Did not shop online
# 7      Single-person household    Did not shop online
# 8  Family without children <18  Online shopper (≥ $1)
# 9  Family without children <18  Online shopper (≥ $1)

# %%
print("unique values per column:\n",cius_df.nunique())
# Out:
# unique values per column:
#  Province                 10
# Age                       7
# Gender                    2
# Education                 4
# Employment                3
# Income_Group              5
# Weight                 2953
# Rel_Satisfaction          6
# Online_Contact_Freq       7
# SM_Interfere_Rel          3
# SM_Interfere_Life         3
# SM_Anxious_Envious        3
# SM_AI_Chatbot             3
# SM_AI_Email               3
# Household_Type            4
# Online_Shopping           3
# dtype: int64

# %%
print("column types:\n",cius_df.dtypes)
# Out:
# column types:
#  Province                   str
# Age                        str
# Gender                     str
# Education                  str
# Employment                 str
# Income_Group               str
# Weight                 float64
# Rel_Satisfaction           str
# Online_Contact_Freq        str
# SM_Interfere_Rel           str
# SM_Interfere_Life          str
# SM_Anxious_Envious         str
# SM_AI_Chatbot              str
# SM_AI_Email                str
# Household_Type             str
# Online_Shopping            str
# dtype: object

# %% [markdown]
# #### Missing Value

# %%
mv = cius_df.isna().sum().to_frame("missing")
mv["percent"] = (mv["missing"] / len(cius_df) * 100).round(2)
mv.sort_values("percent", ascending=False)
# Out:
#                      missing  percent
# Province                   0      0.0
# Age                        0      0.0
# Gender                     0      0.0
# Education                  0      0.0
# Employment                 0      0.0
# Income_Group               0      0.0
# Weight                     0      0.0
# Rel_Satisfaction           0      0.0
# Online_Contact_Freq        0      0.0
# SM_Interfere_Rel           0      0.0
# SM_Interfere_Life          0      0.0
# SM_Anxious_Envious         0      0.0
# SM_AI_Chatbot              0      0.0
# SM_AI_Email                0      0.0
# Household_Type             0      0.0
# Online_Shopping            0      0.0

# %% [markdown]
# #### frequency tables for key demographics

# %%
for col in ["Province", "Age", "Gender", "Education", "Employment", "Income_Group"]:
    print(f"\n=== {col} ===")
    vc = cius_df[col].value_counts(dropna=False)
    pct = (vc / vc.sum() * 100).round(1)
    display(pd.DataFrame({"count": vc, "%": pct}))
# Out:
# === Province ===
#                            count     %
# Province
# Ontario                     6462  25.7
# Quebec                      5665  22.6
# British Columbia            3371  13.4
# Alberta                     2016   8.0
# Saskatchewan                1532   6.1
# Manitoba                    1496   6.0
# Nova Scotia                 1308   5.2
# Newfoundland and Labrador   1191   4.7
# Prince Edward Island        1064   4.2
# New Brunswick               1013   4.0
# === Age ===
#                    count     %
# Age
# 65 years and over   8346  33.2
# 55–64 years         5190  20.7
# 35–44 years         4022  16.0
# 45–54 years         3875  15.4
# 25–34 years         2756  11.0
# 15–24 years          926   3.7
# Unknown                3   0.0
# === Gender ===
#         count     %
# Gender
# Female  13260  52.8
# Male    11858  47.2
# === Education ===
#                                          count     %
# Education
# Some post-secondary (incl. certificate)   8327  33.2
# University degree                         8235  32.8
# High school or less                       7186  28.6
# Unknown                                   1370   5.5
# === Employment ===
#               count     %
# Employment
# Employed      13197  52.5
# Not employed  10500  41.8
# Unknown        1421   5.7
# === Income_Group ===
#                      count     %
# Income_Group
# $42,257 – $72,366     5238  20.9
# $72,367 – $107,480    5190  20.7
# $107,481 – $163,750   5178  20.6
# ≥ $163,751            4916  19.6
# ≤ $42,256             4596  18.3

# %% [markdown]
# # EDA

# %% [markdown]
# #### Older Canadians are well represented in this dataset, so your social media and mental health patterns will reflect older demographic behavior more strongly.
# #### When we later compare stress, sleep,Social Media habits by gender, we’ll keep in mind that the dataset has more women, which might slightly bias averages

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# List of final columns for univariate EDA
cols = [
    "Province", "Age", "Gender", "Education", "Employment",
    "Income_Group", 
    "Rel_Satisfaction", "Online_Contact_Freq",
    "SM_Interfere_Rel", "SM_Interfere_Life", "SM_Anxious_Envious",
    "SM_AI_Chatbot", "SM_AI_Email",
    "Household_Type", "Online_Shopping"
]


# Function to plot bar charts for categorical variables
def plot_bar(col):
    plt.figure(figsize=(10, 4))
    cius_16[col].value_counts().plot(kind='bar', color='steelblue')
    plt.title(f"Distribution of {col}", fontsize=14)
    plt.ylabel("Count")
    plt.xticks(rotation=45, ha='right')
    plt.show()


# UNIVARIATE ANALYSIS
for col in cols:
    print(f"----- {col} -----")
    print(cius_16[col].value_counts())
    plot_bar(col)
# Out:
# ----- Province -----
# Province
# Ontario                      6462
# Quebec                       5665
# British Columbia             3371
# Alberta                      2016
# Saskatchewan                 1532
# Manitoba                     1496
# Nova Scotia                  1308
# Newfoundland and Labrador    1191
# Prince Edward Island         1064
# New Brunswick                1013
# Name: count, dtype: int64
# ----- Age -----
# Age
# 65 years and over    8346
# 55–64 years          5190
# 35–44 years          4022
# 45–54 years          3875
# 25–34 years          2756
# 15–24 years           926
# Unknown                 3
# Name: count, dtype: int64
# ----- Gender -----
# Gender
# Female    13260
# Male      11858
# Name: count, dtype: int64
# ----- Education -----
# Education
# Some post-secondary (incl. certificate)    8327
# University degree                          8235
# High school or less                        7186
# Unknown                                    1370
# Name: count, dtype: int64
# ----- Employment -----
# Employment
# Employed        13197
# Not employed    10500
# Unknown          1421
# Name: count, dtype: int64
# ----- Income_Group -----
# Income_Group
# $42,257 – $72,366      5238
# $72,367 – $107,480     5190
# $107,481 – $163,750    5178
# ≥ $163,751             4916
# ≤ $42,256              4596
# Name: count, dtype: int64
# ----- Rel_Satisfaction -----
# Rel_Satisfaction
# Completely satisfied       10532
# Somewhat satisfied          7616
# Neutral                     3514
# Not asked                   2475
# Somewhat dissatisfied        643
# Completely dissatisfied      338
# Name: count, dtype: int64
# ----- Online_Contact_Freq -----
# Online_Contact_Freq
# Everyday                 9924
# A few times a week       6439
# Not asked                4179
# 2–3 times a month        1540
# Once a week              1476
# Not in the past month     861
# Once a month              699
# Name: count, dtype: int64
# ----- SM_Interfere_Rel -----
# SM_Interfere_Rel
# No           21315
# Not asked     2231
# Yes           1572
# Name: count, dtype: int64
# ----- SM_Interfere_Life -----
# SM_Interfere_Life
# No           18429
# Yes           4458
# Not asked     2231
# Name: count, dtype: int64
# ----- SM_Anxious_Envious -----
# SM_Anxious_Envious
# No           18750
# Yes           4137
# Not asked     2231
# Name: count, dtype: int64
# ----- SM_AI_Chatbot -----
# SM_AI_Chatbot
# No           12539
# Yes           9563
# Not asked     3016
# Name: count, dtype: int64
# ----- SM_AI_Email -----
# SM_AI_Email
# No           12059
# Yes          10043
# Not asked     3016
# Name: count, dtype: int64
# ----- Household_Type -----
# Household_Type
# Family without children <18    11497
# Single-person household         7389
# Family with children <18        5501
# Not asked                        731
# Name: count, dtype: int64
# ----- Online_Shopping -----
# Online_Shopping
# Online shopper (≥ $1)    17175
# Did not shop online       5476
# Not asked                 2467
# Name: count, dtype: int64

# %% [markdown]
# `1. Province`
# >  Shows which provinces had the most respondents.
# - Ontario & Quebec dominate (largest population), followed by BC & Alberta.
#
# `2. Age`
# > Distribution of respondents across 6 age groups.
# - Older groups (55–64 & 65+) have the highest representation.
#
# `3. Gender`
# > Male / Female.
# - Slight female majority (around ~52%).
#
# `4. Education`
# > Three categories + Unknown.
# - Largest group: University graduates.
# - Second: Some post-secondary.
#
# `5. Employment`
# > Employed / Not employed / Unknown.
# - Most respondents are employed.
#
# `6. Income_Group`
# > Income quintiles.
# - Even distribution (by design of quintile sampling).
#
#
# `7. Rel_Satisfaction`
# > (1–5 satisfaction with relationships)
# - Most respondents are “Somewhat satisfied” or “Completely satisfied”.
#
# `8. Online_Contact_Freq`
# > How often they use the internet to contact friends.
# - Biggest groups:
# - ✔ Everyday
# - ✔ A few times a week
#
# This aligns with modern digital behavior.
#
# `9. SM_Interfere_Rel`
# > Does online use interfere with relationships?
# - Majority say No, a minority says Yes.
#
# `10. SM_Interfere_Life`
# > Does online use interfere with life?
# - Most respondents say No — normal finding.
#
# `11. SM_Anxious_Envious`
# > Does online use cause anxiety / envy / depression?
# - Still mostly No, but “Yes” is non-negligible → mental health signal.
#
# `12.  SM_AI_Chatbot`
# > Noticed AI in chatbots?
# - YES is higher here — many Canadians notice chatbots frequently.
#
# `13. SM_AI_Email`
# > Noticed AI in emails?
# - Almost evenly split between Yes/No.
#
# `14.  Household_Type`
# > Household composition.
# - Largest groups:
# - ✔ Family with children
# - ✔ Family without children
# - ✔ Single-person households
#
# `15.  Online_Shopping`
# > Did they shop online?
# - Majority are online shoppers (≥ $1 spent).
# - A smaller segment did not shop online.

# %%
def plot_categorical_heatmap(col1, col2):
    cross = pd.crosstab(cius_16[col1], cius_16[col2])
    plt.figure(figsize=(10,6))
    sns.heatmap(cross, cmap="Blues", annot=True, fmt="d")
    plt.title(f"Heatmap: {col1} vs {col2}")
    plt.ylabel(col1)
    plt.xlabel(col2)
    plt.show()


plot_categorical_heatmap("Age", "SM_Anxious_Envious")
plot_categorical_heatmap("Age", "SM_Interfere_Life")
plot_categorical_heatmap("Online_Contact_Freq", "Rel_Satisfaction")
plot_categorical_heatmap("Province", "Online_Shopping")

# %% [markdown]
# `Heatmap 1: Age vs SM_Anxious_Envious`
# - Shows how many users in each age group said:
#     - Yes ("felt anxious/depressed")
#     - No
#     - Not asked
#
#
# - Younger groups have more Yes responses (common trend).
# - Older groups show more No.
#
# `Heatmap 2: Age vs SM_Interfere_Life`
# - Shows how social media interferes with life based on age.
#
# `Heatmap 3: Online Contact Frequency vs Relationship Satisfaction`
# - X-axis = Satisfaction (1–5)
# - Y-axis = Frequency of contacting friends online
# - People who talk online everyday have a strong cluster in completely satisfied
# - -  "Not asked" remains a valid category because we filled it instead of dropping rows
#
# `Heatmap 4: Province vs Online Shopping`
# - Shows distribution of online shoppers by province.
# - Highest online shopper province
# - Lowest online shopper province

# %% [markdown]
# ## BiVariate Analysis

# %% [markdown]
# ### ` Age × Social Media Mental Health (Anxiety / Interference)`

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=cius_16, x="Age", hue="SM_Anxious_Envious")
plt.xticks(rotation=45)
plt.title("Age vs SM Anxiety/Envy")
plt.show()

# %% [markdown]
# the chart shows:
#
# A bar chart comparing age groups and whether online activities made them feel anxious, depressed, or envious.- Across all age groups, the majority reported “No” to anxiety/envious feelings.
#
# - Younger adults (15–34 years) have higher “Yes” responses, meaning they are more emotionally affected by online activities.
#
# - Older adults (55+ years) show a significant “Not asked” category — meaning they were not active enough online to be asked this question.
#
# - Among those who were asked, the 25–34 and 35–44 groups show the highest rates of anxiety/envious feelings.
#
# - Younger adults appear to be more emotionally vulnerable to effects of social media, consistent with academic literature.

# %%
sns.countplot(data=cius_16, x="Age", hue="SM_Interfere_Life")
plt.xticks(rotation=45)
plt.title("Age vs Online Interference with Life")
plt.show()

# %% [markdown]
# The chart shows:
#
# - How often online activities interfered with daily life (sleep, routine, responsibilities).
#
# - Again, most respondents answered “No” — indicating limited or no interference.
#
# - A large portion of older adults appear as “Not asked” due to CIUS skip logic — they may not use digital platforms enough for the question to apply.
#
# - Digital interference with everyday life is primarily a Adult issue, reflecting heavier online engagement.

# %% [markdown]
# ### `Age × Online Contact Frequency`

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=cius_16, x="Age", hue="Online_Contact_Freq")
plt.xticks(rotation=45)
plt.title("Age vs Online Contact Frequency")
plt.show()

# %% [markdown]
# the chart shows:
#
# How often people use digital tools (social media, messaging) to communicate with friends.
#
#
# - Everyday digital communication is most common among:
#
# - 25–34 years
#
# - 35–44 years
#
# - Older adults (65+) show high “Not asked” responses (due to less internet use).
#
# - Young adults (15–24) show a mix: some daily use, others weekly/monthly communication.
#
# - Digital communication is most frequent among working-age adults (25–44), aligning with social and work demands.

# %% [markdown]
# ### `Online Contact Frequency × Relationship Satisfaction`

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=cius_16, x="Online_Contact_Freq", hue="Rel_Satisfaction")
plt.xticks(rotation=45)
plt.title("Digital Contact Frequency vs Relationship Satisfaction")
plt.show()

# %% [markdown]
# The chart shows:
#
# Whether online communication frequency is linked to satisfaction with relationships.
#
# - Everyday digital contact is strongly associated with:
# - Completely satisfied
# - Somewhat satisfied
# - People who are less satisfied tend to interact digitally less often.
# - “Not asked” appears because some respondents do not use online communication tools.
# - More frequent digital communication correlates with higher relationship satisfaction — suggesting digital contact supports social bonding.

# %% [markdown]
# ### `SM_Interfere_Rel × SM_Anxious_Envious`

# %%
plot_categorical_heatmap("SM_Interfere_Rel", "SM_Anxious_Envious")

# %% [markdown]
# The chart shows:
# Relationship between online interference with relationships and feeling anxious/depressed/envious.
#
# - Most respondents fall under No × No — meaning:
# - Online use did not interfere with relationships
# - They did not feel anxious or envious
# - People who experience interference in relationships also have a higher tendency to report anxiety/envious feelings.
# - “Not asked” category is large for both variables (due to skip logic).
# - Where online activities interfere with relationships, emotional impacts (anxiety/envy) are more likely.

# %% [markdown]
# ### `Province × Online Shopping`

# %%
sns.countplot(data=cius_16, x="Province", hue="Online_Shopping")
plt.xticks(rotation=45)
plt.title("Province vs Online Shopping")
plt.show()

# %% [markdown]
# The chart shows:
#
# How online shopping behavior varies by province.
#
# - Ontario and Quebec have the highest numbers of online shoppers.
# - Provinces with smaller populations (e.g., PEI, NL) naturally show lower counts.
# - The “Not asked” category is minimal because this variable applies to most respondents.
# - Online shopping usage is largely driven by population size and digital adoption, with Ontario and Quebec consistently leading.

# %% [markdown]
# ### `Province × Any Social Media Mental-Health variable`

# %%
sns.countplot(data=cius_16, x="Province", hue="SM_Anxious_Envious")
plt.xticks(rotation=45)
plt.title("Province vs Anxiety from Social Media")
plt.show()

# %% [markdown]
# The chart shows:
#
# How anxiety/envious feelings from online use vary by province.
#
# - Ontario and Quebec have the highest counts — again due to population size.
# - Rates of "Yes" appear fairly evenly distributed by population.
# - Smaller provinces show fewer cases but similar proportions.
# - “Not asked” is present because many respondents do not engage in the online activities needed to receive this question.
# - Emotional responses to online activity appear uniform across provinces, with no province showing extreme differences.

# %% [markdown]
# ## Our Baseline model will predict : Social media usage intensity

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import joblib

# %%
cius_on = cius_16[cius_16["Province"] == "Ontario"].copy()
print("Ontario rows:", cius_on.shape[0])
# Out:
# Ontario rows: 6462

# %%
##Create TARGET: usage_risk

def usage_risk(freq):
    if freq == "Everyday":
        return "High"
    if freq in ["A few times a week", "Once a week"]:
        return "Moderate"
    if freq in ["2–3 times a month", "Once a month", "Not in the past month"]:
        return "Low"
    return None

cius_on["usage_risk"] = cius_on["Online_Contact_Freq"].apply(usage_risk)

# %%
# Drop rows with missing target
cius_model = cius_on.dropna(subset=["usage_risk"]).copy()

print("\nUsage risk distribution:")
print(cius_model["usage_risk"].value_counts())
# Out:
# Usage risk distribution:
# usage_risk
# High        2686
# Moderate    1998
# Low          807
# Name: count, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
# Feature set (X) and target (y)

X = cius_model[
    [
        "Age",
        "Gender",
        "Education",
        "Employment",
        "Income_Group",
        "Household_Type",
        "Online_Shopping",
        "SM_Interfere_Rel",
        "SM_Interfere_Life",
        "SM_Anxious_Envious"
    ]
]

y = cius_model["usage_risk"]

# %%
# Train / test split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
# Preprocessing + Model

categorical_features = X.columns.tolist()

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

model = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("clf", LogisticRegression(
            max_iter=2000,
            multi_class="multinomial"
        ))
    ]
)

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Age', 'Gender', 'Education',
#                                                    'Employment', 'Income_Group',
#                                                    'Household_Type',
#                                                    'Online_Shopping',
#                                                    'SM_Interfere_Rel',
#                                                    'SM_Interfere_Life',
#                                                    'SM_Anxious_Envious'])])),
#                 ('clf',
#                  LogisticRegression(max_iter=2000, multi_class='multinomial'))])

# %%
# Evaluation (BASELINE RESULTS)

y_pred = model.predict(X_test)

print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred, labels=["Low", "Moderate", "High"]))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5013648771610555
#
# Confusion Matrix:
# [[  0  84  77]
#  [  2 152 246]
#  [  0 139 399]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.55      0.74      0.63       538
#          Low       0.00      0.00      0.00       161
#     Moderate       0.41      0.38      0.39       400
#
#     accuracy                           0.50      1099
#    macro avg       0.32      0.37      0.34      1099
# weighted avg       0.42      0.50      0.45      1099

# %%
# Save model (for Flask)
joblib.dump(model, "cius_usage_risk_baseline.pkl")
print("\nModel saved as: cius_usage_risk_baseline.pkl")
# Out:
# Model saved as: cius_usage_risk_baseline.pkl

# %% [markdown]
# We built a multinomial logistic regression baseline. The model performs well for identifying high-usage users but struggles to distinguish low-usage users, highlighting class imbalance and overlapping behavioral patterns

# %% [markdown]
# So instead of this we decided to go with binary classificastion

# %%
cius_on["high_use"] = (cius_on["Online_Contact_Freq"] == "Everyday").astype(int)

# %%
print("\nTarget distribution (high_use):")
print(cius_on["high_use"].value_counts())
# Out:
# Target distribution (high_use):
# high_use
# 0    3776
# 1    2686
# Name: count, dtype: int64

# %%
feature_cols = [
    "Age",
    "Gender",
    "Education",
    "Employment",
    "Income_Group",
    "Household_Type",
    "Online_Shopping",
    "SM_Interfere_Rel",
    "SM_Interfere_Life",
    "SM_Anxious_Envious"
]

# %%
df_model = cius_on.dropna(subset=feature_cols + ["high_use"]).copy()

X = df_model[feature_cols]
y = df_model["high_use"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
preprocessor = ColumnTransformer(
    transformers=[("cat", OneHotEncoder(handle_unknown="ignore"), feature_cols)]
)

clf = LogisticRegression(
    max_iter=2000,
    class_weight="balanced"   # <-- keep this for better minority handling
)

model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("clf", clf)
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Age', 'Gender', 'Education',
#                                                    'Employment', 'Income_Group',
#                                                    'Household_Type',
#                                                    'Online_Shopping',
#                                                    'SM_Interfere_Rel',
#                                                    'SM_Interfere_Life',
#                                                    'SM_Anxious_Envious'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=2000))])

# %%
y_pred = model.predict(X_test)

print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion matrix [ [TN FP], [FN TP] ]:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification report:")
print(classification_report(y_test, y_pred, target_names=["Not-High", "High"]))
# Out:
# Accuracy: 0.6334106728538283
#
# Confusion matrix [ [TN FP], [FN TP] ]:
# [[475 281]
#  [193 344]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#     Not-High       0.71      0.63      0.67       756
#         High       0.55      0.64      0.59       537
#
#     accuracy                           0.63      1293
#    macro avg       0.63      0.63      0.63      1293
# weighted avg       0.64      0.63      0.64      1293

# %%
joblib.dump(model, "cius_highuse_binary_baseline.pkl")
print("\nSaved: cius_highuse_binary_baseline.pkl")
# Out:
# Saved: cius_highuse_binary_baseline.pkl

# %% [markdown]
# The binary logistic regression baseline achieves 63% accuracy with balanced recall across high and non-high social media users, demonstrating that usage intensity is predictable from demographic and behavioral features.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import joblib
import pandas as pd

# -------------------------------------------------
# Assumes you already have these from your baseline:
# X_train, X_test, y_train, y_test
# preprocessor  (ColumnTransformer + OneHotEncoder)
# -------------------------------------------------

rf = RandomForestClassifier(
    n_estimators=400,
    max_depth=None,
    min_samples_leaf=5,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf_model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("rf", rf)
])

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("=== Random Forest Results ===")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("\nConfusion matrix [ [TN FP], [FN TP] ]:")
print(confusion_matrix(y_test, y_pred_rf))
print("\nClassification report:")
print(classification_report(y_test, y_pred_rf, target_names=["Not-High", "High"]))

# Save for Flask (use this if RF wins)
joblib.dump(rf_model, "cius_highuse_random_forest.pkl")
print("\nSaved: cius_highuse_random_forest.pkl")
# Out:
# === Random Forest Results ===
# Accuracy: 0.617169373549884
#
# Confusion matrix [ [TN FP], [FN TP] ]:
# [[448 308]
#  [187 350]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#     Not-High       0.71      0.59      0.64       756
#         High       0.53      0.65      0.59       537
#
#     accuracy                           0.62      1293
#    macro avg       0.62      0.62      0.61      1293
# weighted avg       0.63      0.62      0.62      1293
#
#
# Saved: cius_highuse_random_forest.pkl

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# y_pred = predictions from Logistic Regression on X_test
# y_pred_rf = predictions from Random Forest on X_test

results = pd.DataFrame([
    {
        "Model": "Logistic Regression (Baseline)",
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision (High)": precision_score(y_test, y_pred, pos_label=1),
        "Recall (High)": recall_score(y_test, y_pred, pos_label=1),
        "F1 (High)": f1_score(y_test, y_pred, pos_label=1)
    },
    {
        "Model": "Random Forest",
        "Accuracy": accuracy_score(y_test, y_pred_rf),
        "Precision (High)": precision_score(y_test, y_pred_rf, pos_label=1),
        "Recall (High)": recall_score(y_test, y_pred_rf, pos_label=1),
        "F1 (High)": f1_score(y_test, y_pred_rf, pos_label=1)
    }
])

print(results)
# Out:
#                             Model  Accuracy  Precision (High)  Recall (High)  \
# 0  Logistic Regression (Baseline)  0.633411          0.550400       0.640596
# 1                   Random Forest  0.617169          0.531915       0.651769
#
#    F1 (High)
# 0   0.592083
# 1   0.585774

# %%
import numpy as np
import pandas as pd

feature_names = rf_model.named_steps["preprocess"].get_feature_names_out()
importances = rf_model.named_steps["rf"].feature_importances_

fi = (pd.DataFrame({"feature": feature_names, "importance": importances})
        .sort_values("importance", ascending=False)
        .head(20))

print(fi)
# Out:
#                                             feature  importance
# 27       cat__Online_Shopping_Online shopper (≥ $1)    0.090390
# 5                        cat__Age_65 years and over    0.047727
# 1                              cat__Age_25–34 years    0.044877
# 26                   cat__Online_Shopping_Not asked    0.043392
# 32                 cat__SM_Interfere_Life_Not asked    0.042743
# 29                  cat__SM_Interfere_Rel_Not asked    0.040488
# 4                              cat__Age_55–64 years    0.040238
# 35                cat__SM_Anxious_Envious_Not asked    0.038959
# 33                       cat__SM_Interfere_Life_Yes    0.031821
# 7                                cat__Gender_Female    0.028545
# 13                         cat__Employment_Employed    0.028531
# 25         cat__Online_Shopping_Did not shop online    0.028456
# 36                      cat__SM_Anxious_Envious_Yes    0.027933
# 11                 cat__Education_University degree    0.027677
# 0                              cat__Age_15–24 years    0.027675
# 8                                  cat__Gender_Male    0.027498
# 22  cat__Household_Type_Family without children <18    0.026795
# 21     cat__Household_Type_Family with children <18    0.025664
# 34                       cat__SM_Anxious_Envious_No    0.025286
# 17              cat__Income_Group_$42,257 – $72,366    0.024920

# %%
import os

files = [f for f in os.listdir() if f.endswith(".pkl")]
print(files)
# Out:
# ['cius_highuse_binary_baseline.pkl', 'cius_highuse_random_forest.pkl', 'cius_usage_risk_baseline.pkl']

# %%
model = joblib.load("cius_highuse_random_forest.pkl")
print(model)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Age', 'Gender', 'Education',
#                                                    'Employment', 'Income_Group',
#                                                    'Household_Type',
#                                                    'Online_Shopping',
#                                                    'SM_Interfere_Rel',
#                                                    'SM_Interfere_Life',
#                                                    'SM_Anxious_Envious'])])),
#                 ('rf',
#                  RandomForestClassifier(class_weight='balanced',
#                                         min_samples_leaf=5, n_estimators=400,
#                                         n_jobs=-1, random_state=42))])

# %%
model = joblib.load("cius_highuse_binary_baseline.pkl")
print(model.named_steps)
# Out:
# {'preprocess': ColumnTransformer(transformers=[('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['Age', 'Gender', 'Education', 'Employment',
#                                   'Income_Group', 'Household_Type',
#                                   'Online_Shopping', 'SM_Interfere_Rel',
#                                   'SM_Interfere_Life', 'SM_Anxious_Envious'])]), 'clf': LogisticRegression(class_weight='balanced', max_iter=2000)}

# %%
survey = pd.read_csv("Social Media Use & Mental Health Survey (CIUS-Aligned).csv (1)/Social Media Use & Mental Health Survey (CIUS-Aligned).csv")

# %%
survey.head()
# Out:
#                     Timestamp 1. What is your age group?  \
# 0   2025/11/11 7:30:56 AM EST                      35–44
# 1   2025/11/12 8:59:04 AM EST                      25–34
# 2   2025/11/12 3:27:25 PM EST                      35–44
# 3  2026/01/27 11:36:13 AM EST                      15–24
# 4  2026/01/27 11:36:22 AM EST                      25–34
#
#   2. What is your gender?  \
# 0                  Female
# 1                    Male
# 2                  Female
# 3                  Female
# 4                    Male
#
#   3. Which province or territory do you currently live in?  \
# 0                                            Ontario
# 1                                            Ontario
# 2                                            Ontario
# 3                                            Ontario
# 4                                            Ontario
#
#   4. What is your highest level of education?  \
# 0                                       Other
# 1                             Graduate degree
# 2                           Bachelor’s degree
# 3                                       Other
# 4                             College diploma
#
#   5. What is your current employment status?  \
# 0                         Employed part-time
# 1                                    Student
# 2                         Employed full-time
# 3                                    Student
# 4                         Employed part-time
#
#   6. What is your approximate annual household income (before tax)?  \
# 0                                  Less than $40,000
# 1                                  Less than $40,000
# 2                                  Less than $40,000
# 3                                  Less than $40,000
# 4                                  $40,000 – $69,999
#
#   7. Do you own or regularly use a smartphone?  \
# 0                                          Yes
# 1                                          Yes
# 2                                          Yes
# 3                                          Yes
# 4                                          Yes
#
#   8. In the past 3 months, have you used the Internet to do any of the following?  \
# 0  Send or receive emails;Use instant messaging (...
# 1  Send or receive emails;Use instant messaging (...
# 2  Send or receive emails;Use instant messaging (...
# 3  Send or receive emails;Use instant messaging (...
# 4  Send or receive emails;Use instant messaging (...
#
#   9. How many hours per week do you usually spend on the Internet (for all purposes)?  \
# 0                                 Less than 10 hours
# 1                                   20 hours or more
# 2                                         8-12 hours
# 3                                  Less than 5 hours
# 4                                          12+ Hours
#
#   10. How often do you use social media?  \
# 0                                  Daily
# 1                     A few times a week
# 2                    Several times a day
# 3                    Several times a day
# 4                                  Daily
#
#   11. Have you ever taken a break or reduced your social media/internet use because you felt you were spending too much time online?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   12. How confident do you feel doing most things online (e.g., managing privacy, posting, using apps)?  \
# 0                                          Confident
# 1                                     Very confident
# 2                                 Somewhat confident
# 3                                 Somewhat confident
# 4                                 Somewhat confident
#
#   13. Has your online or social media use negatively affected your personal relationships?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   14. Has your online or social media use negatively affected your school, work, or sleep?  \
# 0                                              Sleep
# 1                                              Sleep
# 2                                              Sleep
# 3                                  School/work;Sleep
# 4                                              Sleep
#
#   15. How would you rate your overall mental health?  \
# 0                                          Excellent
# 1                                               Good
# 2                                          Very good
# 3                                          Very good
# 4                                               Good
#
#    16. Overall, how satisfied are you with your life?  \
# 0                                                  9
# 1                                                  8
# 2                                                  8
# 3                                                 10
# 4                                                  7
#
#   17) What do you usually do to maintain your mental well-being? (Optional short answer)
# 0                                    rest more often
# 1    Go on walks, socialize with friends in the area
# 2            Listen to podcast , go to church , run
# 3                                         Meditation
# 4                Take walks, meditate, companionship

# %%
"Survey shape:", survey.shape
# Out:
# ('Survey shape:', (37, 18))

# %%
"Columns:",survey.columns
# Out:
# ('Columns:',
#  Index(['Timestamp', '1. What is your age group?', '2. What is your gender?',
#         '3. Which province or territory do you currently live in?',
#         '4. What is your highest level of education?',
#         '5. What is your current employment status?',
#         '6. What is your approximate annual household income (before tax)?',
#         '7. Do you own or regularly use a smartphone?',
#         '8. In the past 3 months, have you used the Internet to do any of the following?',
#         '9. How many hours per week do you usually spend on the Internet (for all purposes)?',
#         '10. How often do you use social media?',
#         '11. Have you ever taken a break or reduced your social media/internet use because you felt you were spending too much time online?',
#         '12. How confident do you feel doing most things online (e.g., managing privacy, posting, using apps)?',
#         '13. Has your online or social media use negatively affected your personal relationships?',
#         '14. Has your online or social media use negatively affected your school, work, or sleep?',
#         '15. How would you rate your overall mental health?',
#         '16. Overall, how satisfied are you with your life?',
#         '17) What do you usually do to maintain your mental well-being? (Optional short answer)'],
#        dtype='str'))

# %%
survey = survey.rename(columns={
    '1. What is your age group?': 'Age',
    '2. What is your gender?': 'Gender',
    '4. What is your highest level of education?': 'Education',
    '5. What is your current employment status?': 'Employment',
    '6. What is your approximate annual household income (before tax)?': 'Income_Group',
    '13. Has your online or social media use negatively affected your personal relationships?': 'SM_Interfere_Rel',
    '14. Has your online or social media use negatively affected your school, work, or sleep?': 'SM_Interfere_Life'
})

# %%
survey["Household_Type"] = "Unknown"
survey["Online_Shopping"] = "Unknown"
survey["SM_Anxious_Envious"] = "Unknown"

# %%
feature_cols = [
    'Age',
    'Gender',
    'Education',
    'Employment',
    'Income_Group',
    'Household_Type',
    'Online_Shopping',
    'SM_Interfere_Rel',
    'SM_Interfere_Life',
    'SM_Anxious_Envious'
]

survey_features = survey[feature_cols].copy()

# %%
import joblib
model = joblib.load("cius_highuse_binary_baseline.pkl")

# %%
survey["Predicted_High_Use"] = model.predict(survey_features)

survey["Predicted_Group"] = survey["Predicted_High_Use"].map({
    1: "High",
    0: "Not-High"
})

print(survey["Predicted_Group"].value_counts())
# Out:
# Predicted_Group
# Not-High    31
# High         6
# Name: count, dtype: int64

# %%
survey.groupby("Predicted_Group")[
    "15. How would you rate your overall mental health?"
].value_counts(normalize=True)
# Out:
# Predicted_Group  15. How would you rate your overall mental health?
# High             Very good                                             0.500000
#                  Excellent                                             0.166667
#                  Good                                                  0.166667
#                  Poor                                                  0.166667
# Not-High         Good                                                  0.354839
#                  Very good                                             0.290323
#                  Excellent                                             0.225806
#                  Fair                                                  0.064516
#                  Poor                                                  0.064516
# Name: proportion, dtype: float64

# %%
survey.groupby("Predicted_Group")[
    "16. Overall, how satisfied are you with your life?"
].mean()
# Out:
# Predicted_Group
# High        9.000000
# Not-High    7.677419
# Name: 16. Overall, how satisfied are you with your life?, dtype: float64

# %%
survey.groupby("Predicted_Group")[
    "SM_Interfere_Rel"
].value_counts(normalize=True)
# Out:
# Predicted_Group  SM_Interfere_Rel
# High             Yes                 1.000000
# Not-High         No                  0.741935
#                  Yes                 0.258065
# Name: proportion, dtype: float64

# %%
survey.groupby("Predicted_Group")[
    "SM_Interfere_Life"
].value_counts(normalize=True)
# Out:
# Predicted_Group  SM_Interfere_Life
# High             Sleep                              0.500000
#                  School/work;Sleep                  0.500000
# Not-High         Sleep                              0.387097
#                  School/work;Sleep                  0.258065
#                  None of these                      0.225806
#                  School/work                        0.096774
#                  School/work;Sleep;None of these    0.032258
# Name: proportion, dtype: float64

# %%
survey.groupby("Predicted_Group")[
    "15. How would you rate your overall mental health?"
].value_counts(normalize=True)
# Out:
# Predicted_Group  15. How would you rate your overall mental health?
# High             Very good                                             0.500000
#                  Excellent                                             0.166667
#                  Good                                                  0.166667
#                  Poor                                                  0.166667
# Not-High         Good                                                  0.354839
#                  Very good                                             0.290323
#                  Excellent                                             0.225806
#                  Fair                                                  0.064516
#                  Poor                                                  0.064516
# Name: proportion, dtype: float64

# %%
survey.groupby("Predicted_Group")[
    "16. Overall, how satisfied are you with your life?"
].mean()
# Out:
# Predicted_Group
# High        9.000000
# Not-High    7.677419
# Name: 16. Overall, how satisfied are you with your life?, dtype: float64

# %%
print(survey.columns)
# Out:
# Index(['Timestamp', 'Age', 'Gender',
#        '3. Which province or territory do you currently live in?', 'Education',
#        'Employment', 'Income_Group',
#        '7. Do you own or regularly use a smartphone?',
#        '8. In the past 3 months, have you used the Internet to do any of the following?',
#        '9. How many hours per week do you usually spend on the Internet (for all purposes)?',
#        '10. How often do you use social media?',
#        '11. Have you ever taken a break or reduced your social media/internet use because you felt you were spending too much time online?',
#        '12. How confident do you feel doing most things online (e.g., managing privacy, posting, using apps)?',
#        'SM_Interfere_Rel', 'SM_Interfere_Life',
#        '15. How would you rate your overall mental health?',
#        '16. Overall, how satisfied are you with your life?',
#        '17) What do you usually do to maintain your mental well-being? (Optional short answer)',
#        'Household_Type', 'Online_Shopping', 'SM_Anxious_Envious',
#        'Predicted_High_Use', 'Predicted_Group'],
#       dtype='str')

# %%
print("Relationship Impact by Predicted Group")

survey.groupby("Predicted_Group")["SM_Interfere_Rel"] \
      .value_counts(normalize=True) \
      .rename("Proportion") \
      .reset_index()
# Out:
# Relationship Impact by Predicted Group
#   Predicted_Group SM_Interfere_Rel  Proportion
# 0            High              Yes    1.000000
# 1        Not-High               No    0.741935
# 2        Not-High              Yes    0.258065

# %% [markdown]
# High group:
#
# 100% reported “Yes”
#
# Not-High group:
#
# ~26% reported “Yes”
#
# ~74% reported “No”
#
# That is a very strong directional difference.
#
# Even with small sample, that pattern is clear:
#
# Predicted High users report substantially more relationship interference.

# %%
print("School / Work / Sleep Impact")
survey.groupby("Predicted_Group")["SM_Interfere_Life"] \
      .value_counts(normalize=True) \
      .rename("Proportion") \
      .reset_index()
# Out:
# School / Work / Sleep Impact
#   Predicted_Group                SM_Interfere_Life  Proportion
# 0            High                            Sleep    0.500000
# 1            High                School/work;Sleep    0.500000
# 2        Not-High                            Sleep    0.387097
# 3        Not-High                School/work;Sleep    0.258065
# 4        Not-High                    None of these    0.225806
# 5        Not-High                      School/work    0.096774
# 6        Not-High  School/work;Sleep;None of these    0.032258

# %% [markdown]
# High group:
#
# 100% reported either sleep or school/work impact
#
# 0% selected “None of these”
#
# Not-High group:
#
# ~23% reported “None”
#
# Impact distributed across categories
#
# Only ~38% reported sleep impact alone
#
# Again, High users show stronger negative impact.

# %%
print("Mental Health Rating Distribution")
survey.groupby("Predicted_Group")[
    "15. How would you rate your overall mental health?"
].value_counts(normalize=True).rename("Proportion").reset_index()
# Out:
# Mental Health Rating Distribution
#   Predicted_Group 15. How would you rate your overall mental health?  \
# 0            High                                          Very good
# 1            High                                          Excellent
# 2            High                                               Good
# 3            High                                               Poor
# 4        Not-High                                               Good
# 5        Not-High                                          Very good
# 6        Not-High                                          Excellent
# 7        Not-High                                               Fair
# 8        Not-High                                               Poor
#
#    Proportion
# 0    0.500000
# 1    0.166667
# 2    0.166667
# 3    0.166667
# 4    0.354839
# 5    0.290323
# 6    0.225806
# 7    0.064516
# 8    0.064516

# %% [markdown]
# High group distribution:
#
# 50% Very good
#
# 16.7% Excellent
#
# 16.7% Good
#
# 16.7% Poor
#
# Not-High group:
#
# Majority Good / Very good / Excellent
#
# Smaller Poor proportion (~6%)
#
# Here:
#
# Differences are smaller
#
# Not clearly worse for High group

# %%
print("Life Satisfaction (numeric comparison)")
survey.groupby("Predicted_Group")[
    "16. Overall, how satisfied are you with your life?"
].mean()
#Since life satisfaction is numeric (0–10 scale), we compute averages:
# Out:
# Life Satisfaction (numeric comparison)
# Predicted_Group
# High        9.000000
# Not-High    7.677419
# Name: 16. Overall, how satisfied are you with your life?, dtype: float64

# %% [markdown]
# High: 9.0
# Not-High: 7.68
#
# This is unexpected.
#
# Heavy users reporting higher life satisfaction is counter to typical assumptions.
#
# But:
#
# High group n = 6
#
# One or two strong scores can shift the mean
#
# Could reflect age differences or sample bias

# %% [markdown]
# In a small exploratory survey (n=37), respondents predicted as high social media users were substantially more likely to report relationship and sleep/work interference. However, differences in self-rated mental health and life satisfaction were less consistent, potentially due to the small sample size.

# %%
import pandas as pd

# Filter Ontario
cius_on = cius[cius["Province"] == "Ontario"].copy()

# Binary target: 1 = High usage (Everyday), 0 = Not-High
cius_on["high_use"] = (cius_on["Online_Contact_Freq"] == "Everyday").astype(int)

feature_cols = [
    "Age",
    "Gender",
    "Education",
    "Employment",
    "Income_Group",
    "Household_Type",
    "Online_Shopping",
    "SM_Interfere_Rel",
    "SM_Interfere_Life",
    "SM_Anxious_Envious"
]

df_ml = cius_on[feature_cols + ["high_use"]].dropna().copy()

print(df_ml.shape)
print(df_ml["high_use"].value_counts())
# Out:
# (5503, 11)
# high_use
# 0    3066
# 1    2437
# Name: count, dtype: int64

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
import joblib

ann = MLPClassifier(
    hidden_layer_sizes=(64, 32),   # 2 hidden layers
    activation="relu",
    solver="adam",
    alpha=0.0005,
    batch_size=32,
    learning_rate_init=0.001,
    max_iter=500,
    random_state=42,
    early_stopping=True,
    validation_fraction=0.1
)

ann_model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("ann", ann)
])

ann_model.fit(X_train, y_train)

y_pred_ann = ann_model.predict(X_test)

print("=== ANN Results ===")
print("Accuracy:", accuracy_score(y_test, y_pred_ann))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_ann))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_ann, target_names=["Not-High", "High"]))

joblib.dump(ann_model, "cius_highuse_ann.pkl")
print("\nSaved: cius_highuse_ann.pkl")
# Out:
# === ANN Results ===
# Accuracy: 0.6442382057231245
#
# Confusion Matrix:
# [[518 238]
#  [222 315]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Not-High       0.70      0.69      0.69       756
#         High       0.57      0.59      0.58       537
#
#     accuracy                           0.64      1293
#    macro avg       0.63      0.64      0.64      1293
# weighted avg       0.65      0.64      0.64      1293
#
#
# Saved: cius_highuse_ann.pkl
